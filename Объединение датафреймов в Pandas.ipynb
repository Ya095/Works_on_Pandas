# %%
import pandas as pd

# %%
df = pd.read_excel('new_file.xlsx')
df
# Out:
#        Order ID                     Product  Quantity     Price  \
# 0        295665          Macbook Pro Laptop         1   1700.00
# 1        295666          LG Washing Machine         1    600.00
# 2        295667        USB-C Charging Cable         1  35004.00
# 3        295668            27in FHD Monitor         1    149.99
# 4        295669        USB-C Charging Cable         1  35004.00
# ...         ...                         ...       ...       ...
# 24984    319666    Lightning Charging Cable         1     14.95
# 24985    319667       AA Batteries (4-pack)         2  30742.00
# 24986    319668             Vareebadd Phone         1    400.00
# 24987    319669            Wired Headphones         1  36465.00
# 24988    319670  Bose SoundSport Headphones         1     99.99
#
#                 Order Date                        Purchase Address     Total
# 0           12/30/19 00:01  136 Church St, New York City, NY 10001   1700.00
# ...

# %%
df.shape
# Out:
# (24989, 7)

# %%
num = 1
for i in range(0, df.shape[0], 5000):
    tmp = df.iloc[i: i+5000-1]
    tmp.to_excel(f'new_data/part_{num}.xlsx', index=False)
    num += 1

# %%
df.iloc[0]
# Out:
# Order ID                                            295665
# Product                                 Macbook Pro Laptop
# Quantity                                                 1
# Price                                               1700.0
# Order Date                                  12/30/19 00:01
# Purchase Address    136 Church St, New York City, NY 10001
# Total                                               1700.0
# Name: 0, dtype: object

# %%
import os

# %%
df_all = pd.DataFrame()
for f in reversed(os.listdir('new_data/')):
    tmp = pd.read_excel('new_data/' + f)
    df_all = pd.concat([df_all, tmp])

df_all
# Out:
#       Order ID                     Product  Quantity     Price  \
# 0       295665          Macbook Pro Laptop         1   1700.00
# 1       295666          LG Washing Machine         1    600.00
# 2       295667        USB-C Charging Cable         1  35004.00
# 3       295668            27in FHD Monitor         1    149.99
# 4       295669        USB-C Charging Cable         1  35004.00
# ...        ...                         ...       ...       ...
# 4984    319666    Lightning Charging Cable         1     14.95
# 4985    319667       AA Batteries (4-pack)         2  30742.00
# 4986    319668             Vareebadd Phone         1    400.00
# 4987    319669            Wired Headphones         1  36465.00
# 4988    319670  Bose SoundSport Headphones         1     99.99
#
#                Order Date                        Purchase Address     Total
# 0          12/30/19 00:01  136 Church St, New York City, NY 10001   1700.00
# ...
